# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sinfo=pd.read_csv("subject-info.csv")

# %%
ecg_data=pd.read_csv("test_measure.csv")
# remove values of RR too big
ecg_data = ecg_data[~((ecg_data['RR'] > 1000) & (ecg_data['power'] > 0))]
#df.drop(df['RR']>1000)

ecg_data
# Out:
#        ID     time     RR       VO2  power
# 0       1 -130.840  672.0  0.302008      0
# 1       1 -130.168  672.0  0.302008      0
# 2       1 -129.536  632.0  0.301336      0
# 3       1 -128.824  712.0  0.301336      0
# 4       1 -127.948  876.0  0.301336      0
# ...    ..      ...    ...       ...    ...
# 52057  18  947.288  536.0  0.507071      0
# 52058  18  947.816  528.0  0.507071      0
# 52059  18  948.344  528.0  0.507071      0
# 52060  18  948.884  540.0  0.507071      0
# 52061  18  949.424  540.0  0.507071      0
#
# [52055 rows x 5 columns]

# %%
ecg_data_c = ecg_data.copy()

# %%
# remove RR values way above their surrounding value
ecg_data_c['RR_av'] = ecg_data_c.groupby('ID')['RR'].rolling(201).median().values
ecg_data_c = ecg_data_c[~((ecg_data_c['RR'] > ecg_data_c['RR_av']*2) | (ecg_data_c['RR'] < 0.5*ecg_data_c['RR_av']))]
ecg_data_c.drop(columns=['RR_av'], inplace=True)

ecg_data_c
# Out:
#        ID     time     RR       VO2  power  diffRR  diffRR_av     pb pb_before
# 0       1 -130.840  672.0  0.302008      0     NaN        NaN  False       NaN
# 1       1 -130.168  672.0  0.302008      0     0.0        NaN  False     False
# 2       1 -129.536  632.0  0.301336      0    40.0        NaN  False     False
# 3       1 -128.824  712.0  0.301336      0    80.0        NaN  False     False
# 4       1 -127.948  876.0  0.301336      0   164.0        NaN  False     False
# ...    ..      ...    ...       ...    ...     ...        ...    ...       ...
# 52057  18  947.288  536.0  0.507071      0     8.0        8.0  False     False
# 52058  18  947.816  528.0  0.507071      0     8.0        8.0  False     False
# 52059  18  948.344  528.0  0.507071      0     0.0        8.0  False     False
# 52060  18  948.884  540.0  0.507071      0    12.0        8.0  False     False
# 52061  18  949.424  540.0  0.507071      0     0.0        8.0  False     False
#
# [51877 rows x 9 columns]

# %%
# remove points increasing more than 10 time the normal surrounding increase
for i in range(15):
    print(i+1)
    ecg_data_c['diffRR'] = np.abs(ecg_data_c['RR'].diff())
    ecg_data_c['diffRR_av'] = ecg_data_c.groupby('ID')['diffRR'].rolling(201).median().values
    ecg_data_c['pb'] = (ecg_data_c['diffRR'] > 10*ecg_data_c['diffRR_av']) & (ecg_data_c['diffRR_av'] != 0)
    ecg_data_c['pb_before'] = ecg_data_c.groupby('ID')['pb'].shift(1)
    ecg_data_c.loc[(ecg_data_c['pb'] == 1) & (ecg_data_c['pb_before'] == 1), 'pb'] = 0
    print(ecg_data_c[ecg_data_c['pb'] == 1]['pb'].sum()/ecg_data_c.shape[0])
    ecg_data_c = ecg_data_c[ecg_data_c['pb'] == 0]
# Out:
# 1
# 0.0026127718435410745
# 2
# 0.0004237614608213268
# 3
# 5.781015146259683e-05
# 4
# 3.85423291129483e-05
# 5
# 3.854381468133901e-05
# 6
# 1.9272650182126543e-05
# 7
# 1.9273021624330263e-05
# 8
# 1.9273393080851885e-05
# 9
# 1.9273764551692237e-05
# 10
# 1.9274136036852148e-05
# 11
# 1.9274507536332445e-05
# 12
# 1.927487905013396e-05
# 13
# 1.9275250578257516e-05
# 14
# 1.9275622120703946e-05
# 15
# 1.9275993677474075e-05

# %%
ecg_data_c.shape
# Out:
# (51877, 9)

# %%
ecg_data = ecg_data.merge(ecg_data_c[['ID', 'time']], how='left', on=['ID', 'time'])
ecg_data['remain']=None
ecg_data['remain'] = ecg_data['remain'].fillna(0)

# %%
# Define test sequence
ecg_data['power_idx'] = (ecg_data.groupby('ID')['power']
                         .apply(lambda x: (x != x.shift()).cumsum()))
tmp = ecg_data.groupby('ID')['power_idx'].max().reset_index()
tmp = tmp.rename(columns={'power_idx': 'last_power_idx'})
ecg_data = ecg_data.merge(tmp, on='ID', how='left')
ecg_data['test']=None
ecg_data['test'] = np.select(
    [
        ecg_data['power_idx'] == 1,
        ecg_data['power_idx'] == ecg_data['last_power_idx']
    ],
    [
        'rest',
        'recovery'
    ],
   # default='test'
)
# Out:
# C:\Users\garin\AppData\Local\Temp\ipykernel_6580\1980378269.py:3: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   .apply(lambda x: (x != x.shift()).cumsum()))

# %%
ecg_data.columns
# Out:
# Index(['ID', 'time', 'RR', 'VO2', 'power', 'remain', 'power_idx',
#        'last_power_idx_x', 'test', 'last_power_idx_y', 'last_power_idx'],
#       dtype='object')

# %%
ecg_data.shape
# Out:
# (52055, 11)

# %%
ecg_data.head()
# Out:
#    ID     time     RR       VO2  power  remain  power_idx  last_power_idx_x  \
# 0   1 -130.840  672.0  0.302008      0       0          1                11
# 1   1 -130.168  672.0  0.302008      0       0          1                11
# 2   1 -129.536  632.0  0.301336      0       0          1                11
# 3   1 -128.824  712.0  0.301336      0       0          1                11
# 4   1 -127.948  876.0  0.301336      0       0          1                11
#
#    test  last_power_idx_y  last_power_idx
# 0  rest                11              11
# 1  rest                11              11
# 2  rest                11              11
# 3  rest                11              11
# 4  rest                11              11

# %%
# Plot
import matplotlib.pyplot as plt
import seaborn as sns

g = sns.FacetGrid(data=ecg_data, col='ID', col_wrap=5, height=4, aspect=1.2)
g = g.map(plt.plot, 'time', 'power')
g = g.map(plt.fill_between, 'time', y1=0, y2=300, alpha=0.3,hue=test)
g = g.set_ylabels('Power')
g = g.set_xlabels('Time')
plt.ylim(0, 300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       5 g = sns.FacetGrid(data=ecg_data, col='ID', col_wrap=5, height=4, aspect=1.2)
#       6 g = g.map(plt.plot, 'time', 'power')
# ----> 7 g = g.map(plt.fill_between, 'time', y1=0, y2=300, alpha=0.3,hue=test)
#       8 g = g.set_ylabels('Power')
#       9 g = g.set_xlabels('Time')
#
# NameError: name 'test' is not defined

# %%
ecg_data['HR'] = 60000/ecg_data['RR']

# %%
#To calculate HR rest and HR max, we need to group the data by ID and test sequence, and use the following formulas:

# calculate HR rest
hr_rest = ecg_data.groupby(['ID'])['HR'].mean()
hr_rest
# Out:
# ID
# 1     155.110805
# 2     139.277158
# 3     136.647228
# 4     149.006665
# 5     145.540187
# 6     136.729146
# 7     144.863255
# 8     137.697140
# 9     153.356769
# 10    150.288667
# 11    139.525120
# 12    141.916278
# 13    143.114138
# 14    143.161240
# 15    144.940373
# 16    142.722150
# 17    138.980231
# 18    146.146378
# Name: HR, dtype: float64

# %%
# calculate HR max and HRR
ecg_data['power_idx'] = (ecg_data['power'] != ecg_data['power'].shift()).cumsum()
max_data = ecg_data.groupby(['ID', 'power_idx']).agg(
    HRmax=('HR', 'max'),
    VO2max_abs=('VO2', 'max'),
    powermax=('power', 'max')
).groupby(['ID']).agg(
    HRmax=('HRmax', 'max'),
    VO2max_abs=('VO2max_abs', 'max'),
    powermax=('powermax', 'max')
)


max_data
# Out:
#          HRmax  VO2max_abs  powermax
# ID
# 1   197.368421    1.789775       170
# 2   197.368421    1.959791       140
# 3   182.926829    3.455253       305
# 4   223.880597    3.437170       305
# 5   189.873418    3.386349       275
# 6   202.702703    3.415759       245
# 7   238.095238    1.658511       170
# 8   200.000000    1.994151       170
# 9   200.000000    1.742767       200
# 10  192.307692    2.352912       200
# 11  194.805195    3.353922       335
# 12  197.368421    3.868313       305
# 13  189.873418    4.576774       320
# 14  211.267606    2.482935       230
# 15  205.479452    2.993701       215
# 16  189.873418    3.451169       230
# 17  189.873418    2.205942       185
# 18  197.368421    2.204238       200

# %%
sinfo['MaxHR']=220-sinfo['age']

# %%
df = pd.merge(sinfo, max_data, on='ID')

# %%
df1=pd.merge(df,hr_rest,on='ID')
df1
# Out:
#     ID  age  Weight  Height  P_vt1  P_vt2      sport  MaxHR       HRmax  \
# 0    1   15    53.7     161     50    140    fencing    205  197.368421
# 1    2   15    56.2     162     80    127    fencing    205  197.368421
# 2    3   16    89.9     191    155    300    fencing    204  182.926829
# 3    4   16    76.5     180    215    275    fencing    204  223.880597
# 4    5   17    76.4     186    110    172    fencing    203  189.873418
# 5    6   17    65.6     169    131    186    fencing    203  202.702703
# 6    7   15    49.8     165     65    108    fencing    205  238.095238
# 7    8   15    51.2     165     80    133    fencing    205  200.000000
# 8    9   14    57.1     176     50    125    fencing    206  200.000000
# 9   10   14    58.8     177    101    162    fencing    206  192.307692
# 10  11   18    84.8     182    174    268      kayak    202  194.805195
# 11  12   18    86.0     183    170    294      kayak    202  197.368421
# 12  13   18    83.9     183    144    267      kayak    202  189.873418
# 13  14   13    62.3     171    140    170      kayak    207  211.267606
# 14  15   13    63.5     172    125    156      kayak    207  205.479452
# 15  16   16    70.4     182     79    175      kayak    204  189.873418
# 16  17   12    39.9     156    101    145  triathlon    208  189.873418
# 17  18   12    39.7     158     65    168  triathlon    208  197.368421
#
#     VO2max_abs  powermax          HR
# 0     1.789775       170  155.110805
# 1     1.959791       140  139.277158
# 2     3.455253       305  136.647228
# 3     3.437170       305  149.006665
# 4     3.386349       275  145.540187
# 5     3.415759       245  136.729146
# 6     1.658511       170  144.863255
# 7     1.994151       170  137.697140
# 8     1.742767       200  153.356769
# 9     2.352912       200  150.288667
# 10    3.353922       335  139.525120
# 11    3.868313       305  141.916278
# 12    4.576774       320  143.114138
# 13    2.482935       230  143.161240
# 14    2.993701       215  144.940373
# 15    3.451169       230  142.722150
# 16    2.205942       185  138.980231
# 17    2.204238       200  146.146378

# %%
time_rest = ecg_data[ecg_data['test']=='recovery'].groupby(['ID']).first()['time']

# %%
df1=pd.merge(df1,time_rest,on='ID')

# %%
df1['Vo2inmL/Kg/min']=df1['VO2max_abs']*1000/df1['Weight']
df1
# Out:
#     ID  age  Weight  Height  P_vt1  P_vt2      sport  MaxHR       HRmax  \
# 0    1   15    53.7     161     50    140    fencing    205  197.368421
# 1    2   15    56.2     162     80    127    fencing    205  197.368421
# 2    3   16    89.9     191    155    300    fencing    204  182.926829
# 3    4   16    76.5     180    215    275    fencing    204  223.880597
# 4    5   17    76.4     186    110    172    fencing    203  189.873418
# 5    6   17    65.6     169    131    186    fencing    203  202.702703
# 6    7   15    49.8     165     65    108    fencing    205  238.095238
# 7    8   15    51.2     165     80    133    fencing    205  200.000000
# 8    9   14    57.1     176     50    125    fencing    206  200.000000
# 9   10   14    58.8     177    101    162    fencing    206  192.307692
# 10  11   18    84.8     182    174    268      kayak    202  194.805195
# 11  12   18    86.0     183    170    294      kayak    202  197.368421
# 12  13   18    83.9     183    144    267      kayak    202  189.873418
# 13  14   13    62.3     171    140    170      kayak    207  211.267606
# 14  15   13    63.5     172    125    156      kayak    207  205.479452
# 15  16   16    70.4     182     79    175      kayak    204  189.873418
# 16  17   12    39.9     156    101    145  triathlon    208  189.873418
# 17  18   12    39.7     158     65    168  triathlon    208  197.368421
#
#     VO2max_abs  powermax          HR  Vo2inmL/Kg/min      time
# 0     1.789775       170  155.110805       33.329152   654.180
# 1     1.959791       140  139.277158       34.871720   514.980
# 2     3.455253       305  136.647228       38.434406  1153.336
# 3     3.437170       305  149.006665       44.930322  1168.112
# 4     3.386349       275  145.540187       44.323937  1082.308
# 5     3.415759       245  136.729146       52.069497   906.180
# 6     1.658511       170  144.863255       33.303437   608.028
# 7     1.994151       170  137.697140       38.948254   638.540
# 8     1.742767       200  153.356769       30.521318   692.240
# 9     2.352912       200  150.288667       40.015518   752.276
# 10    3.353922       335  139.525120       39.550972  1268.132
# 11    3.868313       305  141.916278       44.980380  1198.980
# 12    4.576774       320  143.114138       54.550343  1209.072
# 13    2.482935       230  143.161240       39.854500   869.144
# 14    2.993701       215  144.940373       47.144893   805.568
# 15    3.451169       230  142.722150       49.022283   898.972
# 16    2.205942       185  138.980231       55.286765   677.396
# 17    2.204238       200  146.146378       55.522363   748.004
